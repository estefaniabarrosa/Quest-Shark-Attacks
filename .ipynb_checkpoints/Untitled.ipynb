# %%
import pandas as pd
import xlrd

workbook = pd.read_excel("C:\Users\durga\Downloads\GSAF5.xls")
workbook
# Out:
#   Cell In[5], line 4
#     workbook = pd.read_excel("C:\Users\durga\Downloads\GSAF5.xls")
#                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
